# %% [markdown]
# # Test spaCy/TreeTagger

# %% [markdown]
# Essais décomposition et affichage sous forme de graphe :

# %%
import pandas as pd

reviews = pd.DataFrame(pd.read_csv("reviews.csv",sep="|",header = None)[1])

# %%
echantillon = reviews.sample(10)


echantillon.to_csv("sample.csv",sep="|",index=False,header=None)
display(echantillon)
# Out:
#                                                       1
# 869   Seule chose à dire de positif à dire sur cet h...
# 1319  Nous avons été tout compris pour une semaine e...
# 7143  Nous venons de passer une semaine ici, été plu...
# 3840  Nous venons juste de ce bel hôtel. Nous étions...
# 2192  Hôtel fantastique.Ignorez tous les commentaire...
# 147   Navette pour la plage, supermarché juste en fa...
# 477   Deuxième séjour en cinq ans. L'hôtel a été rén...
# 3898  Nous sommes venus ici avec des amis pour fêter...
# 5902  Nous venons de passer une semaine dans cet hôt...
# 6181  Mon mari et moi avons récemment (septembre à 2...

# %%
reviews = pd.read_csv("sample.csv",sep="|",header = None)

# %%
display(reviews)
# Out:
#                                                    0
# 0  Seule chose à dire de positif à dire sur cet h...
# 1  Nous avons été tout compris pour une semaine e...
# 2  Nous venons de passer une semaine ici, été plu...
# 3  Nous venons juste de ce bel hôtel. Nous étions...
# 4  Hôtel fantastique.Ignorez tous les commentaire...
# 5  Navette pour la plage, supermarché juste en fa...
# 6  Deuxième séjour en cinq ans. L'hôtel a été rén...
# 7  Nous sommes venus ici avec des amis pour fêter...
# 8  Nous venons de passer une semaine dans cet hôt...
# 9  Mon mari et moi avons récemment (septembre à 2...

# %%
avis = reviews.to_json(orient="records",force_ascii=False)
print(avis)
# Out:
# [{"0":"Comme un \"hôtel de 100 chambres\", je dirais que c'ordinaire, bien que je ne suis pas un ami de grands hôtels. Nous avons apprécié d'espace de notre chambre et la vue sur la mer. Demandez une chambre avec vue sur la mer et la piscine de aux derniers étages (nous avions une suite). Personnel de ménage était excellent, même pour les enfants était petites choses rangée chaque jour :-) Nous avons aussi beaucoup aimé la piscine. Le petit déjeuner continental habituel, sauf Nous avons trouvé un peu de moisissure dans un melon un matin... Le personnel de la réception ne sont pas des plus chaleureux !"},{"0":"7 Jours de luxe à cet hôtel. Ils ont besoin d'une société ou demi-pension ou pension complète. Le petit déjeuner est très complet, et commencerez votre journée du bon pied, car il y a des bus jusqu'à 11 h. Ils ont leur propre restaurant où je vous revoir bientôt. Nous avions une suite junior qui était assez grande, avec un petit coin salon et un jardin. Le village est petit et i
# ...

# %%
list_avis = [
    "Comme un hôtel de 100 chambres, je dirais que c'ordinaire, bien que je ne suis pas un ami de grands hôtels. Nous avons apprécié d'espace de notre chambre et la vue sur la mer. Demandez une chambre avec vue sur la mer et la piscine de aux derniers étages (nous avions une suite). Personnel de ménage était excellent, même pour les enfants était petites choses rangée chaque jour :-) Nous avons aussi beaucoup aimé la piscine. Le petit déjeuner continental habituel, sauf Nous avons trouvé un peu de moisissure dans un melon un matin... Le personnel de la réception ne sont pas des plus chaleureux !",
ir sur les rochers en face de la mer, très agréable de s'asseoir et écouter les vagues s'écraser sur les rochers. L'équipe d'animation, Andrea et Sara étaient vraiment cool et sympa. Ils ont organisé ... watervolley, club enfants, tennis de table, etc. Nous avons participé à la table tournoi de tennis qui était vraiment amusant. La piscine à débordement était incroyable. Il y avait beaucoup de chaises longues, lits et jacuzzis de massage.Hôtel fantastique. Vraiment je vous le recommande !",
    "L'hôtel était propre et ordonné, le personnel très serviable nous avons demandé une bouilloire pour notre chambre et nous avons eu une avec thé et café sans frais supplémentaires. Il y avait plein de transats et une bonne qualité est aussi le restaurant buffet était correct on pouvait toujours trouver quelque chose que nous avons bien aimé l'hôtel est bien situé à environ 20 minutes à pied de la plage et il y a beaucoup de magasins et restaurants à proximité."
]

# %%
tags = {
    "VER:cond":"VERB",
    "VER:futu":"VERB",
    "VER:impe":"VERB",
    "VER:impf":"VERB",
    "VER:infi":"VERB",
    "VER:pper":"VERB",
    "VER:ppre":"VERB",
    "VER:pres":"VERB",
    "VER:simp":"VERB",
    "VER:subi":"VERB",
    "VER:subp":"VERB",
    "VERB" : "VERB",
    "SYM" :"SYM",
    "PUN:cit" : "PUNCT",
    "PUN" : "PUNCT",
    "PUNCT" : "PUNCT",
    "NAM" : "PROPN",
    "PROPN" : "PROPN",
    "NOM" : "NOUN",
    "NOUN" : "NOUN",
    "NUM" : "NUM",
    "PRP" : "ADP",
    "PRP:det" : "DET",
    "ADP" : "ADP",
    "PRO" : "PRON",
    "PRO:DEM" : "PRON",
    "PRO:IND" : "PRON",
    "PRO:PER" : "PRON",
    "PRO:POS" : "PRON",
    "PRO:REL" : "PRON",
    "PRON" : "PRON",
    "CONJ" : "KON",
    "CCONJ" : "KON",
    "SCONJ" : "KON",
    "KON" : "KON",
    "ADV" : "ADV",
    "ADJ" : "ADJ",
    "DET:ART" : "DET",
    "DET:POS" : "DET",
    "DET" : "DET",
    "INT" : "INTJ",
    "INTJ" : "INTJ",
    "PART" : "PART",
    "X" : "X",
    "AUX" : "VERB",
    "SENT" : "PUNCT",
    "ABR" : "X"
}

'''
VERB
SYM
PUNCT
PROPN
NOUN
NUM
ADP
PRON
KON
ADV
ADJ
DET
INTJ
PART
AUX
X
'''
# Out:
# '\nVERB\nSYM\nPUNCT\nPROPN\nNOUN\nNUM\nADP\nPRON\nKON\nADV\nADJ\nDET\nINTJ\nPART\nAUX\nX\n'

# %%
import spacy
import treetaggerwrapper

def posTaggingSpacy(text) :
    nlp = spacy.load("fr_core_news_sm")
    doc = nlp(text)

    list_t =[]

    for token in doc:
        t = {"mot":token.text, "nature": tags[token.pos_],"tag":token.pos_}
        list_t.append(t)
    return list_t



tagger = treetaggerwrapper.TreeTagger(TAGLANG='fr',TAGOPT="-prob -threshold 0.7 -token -lemma -sgml -quiet")

def tagToObj(sentArray): 
    sentTab = []
    for t in sentArray: 
        if len(t) >1 :
            sentTab.append({"mot" : t[0], "nature" : tags[t[1]],"tag":t[1],"acc":t[3]})
    return sentTab

def posTaggingTreeTagger(text) :
    tags = tagger.tag_text(text)
    taggedText = treetaggerwrapper.make_tags(tags,allow_extra = True)
    return tagToObj(taggedText)
# Out:
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:740: FutureWarning: Possible nested set at position 8
#   re.IGNORECASE | re.VERBOSE)
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:2044: FutureWarning: Possible nested set at position 152
#   re.VERBOSE | re.IGNORECASE)
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:2067: FutureWarning: Possible nested set at position 409
#   UrlMatch_re = re.compile(UrlMatch_expression, re.VERBOSE | re.IGNORECASE)
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:2079: FutureWarning: Possible nested set at position 192
#   EmailMatch_re = re.compile(EmailMatch_expression, re.VERBOSE | re.IGNORECASE)

# %%
import re

def suppressionPonct(text) : 
    #replaced = re.sub('[^\w\s]', '', text)
    #replaced = re.sub(r'[^[.,\/#!$%\^&\*;:{}=\-_`~()]]', '', text)
    replaced = text.translate({ord(i): " " for i in '.,\/#!$%\^&\*;:{}=_`~()'})
    replaced = re.sub("\s+"," ",replaced)
    return replaced

# %%
print(suppressionPonct("essatsyi.rrrr"))
# Out:
# essatsyi rrrr

# %%
list_avis = [
    "Comme un hôtel de 100 chambres, je dirais que c'ordinaire, bien que je ne suis pas un ami de grands hôtels. Nous avons apprécié d'espace de notre chambre et la vue sur la mer. Demandez une chambre avec vue sur la mer et la piscine de aux derniers étages (nous avions une suite). Personnel de ménage était excellent, même pour les enfants était petites choses rangée chaque jour :-) Nous avons aussi beaucoup aimé la piscine. Le petit déjeuner continental habituel, sauf Nous avons trouvé un peu de moisissure dans un melon un matin... Le personnel de la réception ne sont pas des plus chaleureux !",
    "7 Jours de luxe à cet hôtel. Ils ont besoin d'une société ou demi-pension ou pension complète. Le petit déjeuner est très complet, et commencerez votre journée du bon pied, car il y a des bus jusqu'à 11 h. Ils ont leur propre restaurant où je vous revoir bientôt. Nous avions une suite junior qui était assez grande, avec un petit coin salon et un jardin. Le village est petit et il y a la plage privée, mais au moins il y en a une ! C'est un endroit parfait pour faire du vélo et se détendre. Location de vélos électriques y compris dans les hôtels.",
    "Je reviens d'une semaine au soleil. Dès l'instant où nous sommes arrivés jusqu'à notre départ, le personnel est poli et courtois. Notre chambre donnait sur la piscine et est bien situé pour les derniers rayons du soleil. Les lits sont très confortables. L'hôtel jardins bien entretenus et un délice pour marcher à travers. La nourriture est aussi excellente. Nous sommes allés sur un couple d'excursions qui nous avons apprécié - jeep safari et observer les dauphins.",
# %%
import string

def findDiff(tag_tree,tag_spacy) : 
    nbr_diff = 0
    nbr_mots = 0
    tab_dif = []
    for i in range(len(tag_tree)):
        nbr_mots = nbr_mots +1
        if tag_spacy[i]["nature"] != tag_tree[i]["nature"] : 
            tab_dif.append({"spacy" : tag_spacy[i], "treetag" : tag_tree[i]})
            nbr_diff = nbr_diff + 1
    return (nbr_diff,nbr_mots,tab_dif)

cpt_diff = 0
cpt_mots = 0
tab_diffs_global = []
for avis in list_avis : 
    phrase = suppressionPonct(avis)
    tag_tree = posTaggingTreeTagger(phrase)
    tag_spacy = posTaggingSpacy(phrase)
    nbr_diff,nbr_mots,diffs = findDiff(tag_tree,tag_spacy)
    cpt_diff = cpt_diff + nbr_diff
    cpt_mots = cpt_mots + nbr_mots
    tab_diffs_global = tab_diffs_global + diffs

print("Nbr diff :")
print(cpt_diff)
print("Nbr mots :")
print(cpt_mots)

display(tab_diffs_global)
# Out:
# Nbr diff :
# 291
# Nbr mots :
# 2331
# [{'spacy': {'mot': 'Comme', 'nature': 'ADP', 'tag': 'ADP'},
#   'treetag': {'mot': 'Comme',
#    'nature': 'ADV',
#    'tag': 'ADV',
#    'acc': (0.518505, 'KON', 'comme', 0.481495)}},
#  {'spacy': {'mot': 'mer', 'nature': 'VERB', 'tag': 'VERB'},
#   'treetag': {'mot': 'mer', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (1.0,)}},
#  {'spacy': {'mot': 'Demandez', 'nature': 'PROPN', 'tag': 'PROPN'},
#   'treetag': {'mot': 'Demandez',
#    'nature': 'VERB',
#    'tag': 'VER:pres',
#    'acc': (0.883895,)}},
#  {'spacy': {'mot': 'mer', 'nature': 'VERB', 'tag': 'VERB'},
#   'treetag': {'mot': 'mer', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (1.0,)}},
#  {'spacy': {'mot': 'aux', 'nature': 'ADJ', 'tag': 'ADJ'},
#   'treetag': {'mot': 'aux', 'nature': 'DET', 'tag': 'PRP:det', 'acc': (1.0,)}},
#  {'spacy': {'mot': 'étages', 'nature': 'PROPN', 'tag': 'PROPN'},
#   'treetag': {'mot': 'étages',
#    'nature': 'NOUN',
#    'tag': 'NOM',
#    'acc': (0.978175,)}},
# ...

# %%
list_terme = {
    "bel" : "ADJ",
    "canaria" : "PROPN",
    "palace" : "PROPN",
    "san": "PROPN",
    "del":"PROPN",
    "inglés" :"PROPN",
    "satisfaits" : "VERB",
    "satisfaites" : "VERB",
    "satisfaite" : "VERB",
    "satisfait" : "VERB",
    "océan": "NOUN",
    "fourni": "VERB",
    "il" : "PRON",
    "ils" : "PRON",
    "elle" : "PRON",
    "elles" : "PRON",
    "cet" : "DET",
    "cette" : "DET",
    "comme" : "KON",
    "mer" : "NOUN",
    "demandez" : "VERB",
    "étages" : "NOUN",
    "personnel" : "NOUN",
    "excellent" : "ADJ",
    "chaque" : "DET",
    "vraiment" : "ADV",
    "restaurant" : "NOUN",
    "restaurants" : "NOUN",
    "déjeuner" : "NOUN",
    "aux" : "DET",
    "au" : "DET",
    "café" : "NOUN",
    "quelque" : "ADJ",
    "quelques" : "ADJ",
    "quel": "ADJ",
    "quelle": "ADJ",
    "une" : "DET",
    "bar" : "NOUN",
    "bars" : "NOUN",
    "recommandons" : "VERB",
    "recommande" : "VERB",
    "si" : "KON",
    "tv" : "NOUN",
    "troisième" : "ADJ",
    "deuxième" : "ADJ",
    "premier" : "ADJ",
    "première" : "ADJ",
    "1er" : "ADJ",
    "7ème" : "ADJ",
    "9ème" : "ADJ",
    "ainsi" : "KON",
    "armoire" : "NOUN",
    "collées" : "VERB",
    "ensemble" : "ADV",
    "notre" : "ADJ",
    "séparée" : "VERB",
    "séparé" : "VERB",
    "tout" : "PRON",
    "tous" : "PRON",
    "très" : "ADV",
    "lever" : "NOUN",
    "coucher" : "NOUN",
    "belles" : "ADJ",
    "belle" : "ADJ",
    "du":"DET",
    "forfait": "NOUN",
    "ne" : "ADV",
    "pas" : "ADV",
    "wifi" : "PROPN",
    "wi-fi":"PROPN",
    "buffets" : "NOUN",
    "buffet" : "NOUN",
    "piscine": "NOUN",
    "plusieurs" : "PRON",
    "plusieur" : "PRON",
    "été" : "VERB",
    "ce":"PRON",
    "c'":"PRON",
    "s'":"PRON",
    "se":"PRON",
    "extérieur" : "NOUN",
    "cava" : "PROPN",
    "jardins" : "NOUN",
    "entretenus" : "VERB",
    "safari" : "NOUN",
    "jeep" : "NOUN",
    "junior" : "ADJ",
    "privée" : "ADJ",
    "compris" : "VERB",
    "dès" : "ADP",
    "apprécié" : "VERB",
    "décevant" : "ADJ",
    "amusant" : "ADJ",
    "que" : "KON",
    "connexion":"NOUN",
    "meublée" : "VERB",
    "drive" : "NOUN",#nom de l'hôtel
    "rien" : "PRON",
    "point" : "NOUN",
    "un" : "DET",
    "une" : "DET",
    "h" : "X",
    "agité" : "VERB",
    "bruyant" : "ADJ",
    "grossier" : "ADJ",
    "croisés" : "VERB",
    "j'": "PRON",
    "hâte" : "VERB",
    "visité" : "VERB",
    "lit": "NOUN",
    "lits": "NOUN",
    "complète" : "ADJ",
    "pour" : "ADP",
    "toujours": "ADV",
    "chaude" : "ADJ",
    "venons" : "VERB",
    "rico" : "PROPN",
    "spar" : "PROPN",
    "sympa" : "ADJ",
    "cool" : "ADJ",
    "collés" : "VERB",
    "aucun" : "PRON",
    "hôtel" : "NOUN",
    "gratuite" : "ADJ",
    "superbe" : "ADJ",
    "futée" : "ADJ",
    "vue" : "NOUN",
    "vous" : "PRON",
    "serviettes" : "NOUN",
    "magasins" : "NOUN",
    "watervolley" : "NOUN",
    "dehors" : "NOUN",
    "aménagé" : "VERB",
    "vagues" : "NOUN",
    "etc" : "X",
    "jacuzzis" : "NOUN",
    "bouilloire" : "NOUN",
    "frais" : "NOUN",
    "correct" : "ADJ",
    "indépendant" : "ADJ",
    "pente" : "NOUN",
    "de" : "ADP",
    "d" : "ADP",
    "le" : "DET",
    "ds" : "ADP",#dans
    "douche" : "NOUN",
    "manque" : "VERB",
    "mais" : "KON",
    "médiocre" : "ADJ",
    "chaud" : "ADJ",
    "lieux" : "NOUN",
    "fort" : "ADV",
    "même" : "ADV",
    "etre" : "VERB",
    "vu" : "VERB",
    "bureau" : "NOUN",
    "solo" : "ADJ",
    "petits" : "ADJ",
    "rapprochés" : "VERB",
    "a" : "ADP",
    "deux" : "ADJ",
    "rare" : "ADJ",
    "classiques" : "ADJ",
    "variées" : "ADJ",
    "sauna" : "NOUN",
    "gym" : "NOUN",
    "abordables" : "ADJ",
    "bémol" : "NOUN",
    "dommage" : "NOUN",
    "vigil" : "NOUN",
    "personnels" : "NOUN",
    "varié" : "ADJ",
    "réduite" : "ADJ",
    "séjour" : "NOUN",
    "fitness" : "NOUN",
    "soins" : "NOUN",
    "massages" : "NOUN",
    "dévoué" : "VERB",
    "dévoués" : "VERB",
    "certains" : "PRON",
    "eviter" : "VERB",
    "produits" : "NOUN",
    "conservés" : "VERB",
    "fruits" : "NOUN",
    "inclus" : "ADJ",
    "offre" : "NOUN",
    "all" : "X",
    "inclusive" : "VERB",
    "l" : "ADP",
    "plats" : "NOUN",
    "poli" :"ADJ",
    "les" : "DET",
    "dîner" : "NOUN",
    "suites" : "NOUN",
    "internet" : "NOUN",
    "radija" : "PROPN",
    "donnes" : "VERB",
    "bon" : "ADJ",
    "moderne" : "ADJ",
    "accueillant" : "ADJ",
    "cuits" : "VERB",
    "playa" : "NOUN"
    
}

nbr_diff_apres_rep = cpt_diff

for diff in tab_diffs_global :
    if diff["spacy"]["mot"].lower() in list(list_terme):
        nbr_diff_apres_rep = nbr_diff_apres_rep-1
    else :
        display(diff)
    
print("nbr diff non géré : ")
print(nbr_diff_apres_rep)
# Out:
# nbr diff non géré :
# 0

# %%
diff_bt_spacy = 0
diff_bt_treetagger = 0

diff_mt_spacy = 0
diff_mt_treetagger = 0

diff_false = 0
nbr_diff = cpt_diff

for diff in tab_diffs_global :
    if diff["spacy"]["mot"].lower() in list(list_terme):
        good_tag = list_terme[diff["spacy"]["mot"].lower()]
        if diff["spacy"]["nature"] == good_tag : 
            diff_bt_spacy = diff_bt_spacy +1
        else : 
            diff_mt_spacy = diff_mt_spacy +1
        if diff["treetag"]["nature"] == good_tag : 
            diff_bt_treetagger = diff_bt_treetagger +1
        else : 
            diff_mt_treetagger = diff_mt_treetagger +1
        
    else :
        display(diff)
    


print("Nbr bon tag tree tagger : ")
print(diff_bt_treetagger)
print("Nbr mauvais tag tree tagger : ")
print(diff_mt_treetagger)

print("Nbr bon tag spacy : ")
print(diff_bt_spacy)
print("Nbr mauvais tags spacy  : ")
print(diff_mt_spacy)

print("Nbr diff : ")
print(nbr_diff)
# Out:
# Nbr bon tag tree tagger :
# 153
# Nbr mauvais tag tree tagger :
# 138
# Nbr bon tag spacy :
# 110
# Nbr mauvais tags spacy  :
# 181
# Nbr diff :
# 291

# %%
print("Accuracy tree tagger : ")
print(diff_bt_treetagger/291)

print("Accuracy SpaCy : ")
print(diff_mt_treetagger/291)
# Out:
# Accuracy tree tagger :
# 0.5257731958762887
# Accuracy SpaCy :
# 0.4742268041237113

# %%
tab_aff_spacy = {}
tab_aff_tree = {}
for diff in tab_diffs_global :
    if diff["spacy"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["spacy"]["mot"].lower()]
        
        if diff["spacy"]["nature"] != ref_tag : 
            tag_spacy = diff["spacy"]["nature"]+ "_" +ref_tag
            if tag_spacy in list(tab_aff_spacy) : 
                tab_aff_spacy[tag_spacy] = tab_aff_spacy[tag_spacy] +1
            else :
                tab_aff_spacy[tag_spacy] = 1
            
        if diff["treetag"]["nature"] != ref_tag : 
            tag_tree = diff["treetag"]["nature"] + "_" +ref_tag
            if tag_tree in list(tab_aff_tree) : 
                tab_aff_tree[tag_tree] = tab_aff_tree[tag_tree] +1
            else :
                tab_aff_tree[tag_tree] = 1

#display(tab_aff_spacy)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(dpi=80)
fig.set_figheight(6)
fig.set_figwidth(12)
fig.suptitle('Erreur SpaCy (tagSpacy_tagRef)',va='baseline')
ax = fig.add_subplot(1,1,1)
ax.yaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.5)
ax.set_axisbelow(True) 
from collections import OrderedDict
ordo = OrderedDict(sorted(tab_aff_spacy.items(), key=lambda t: t[1],reverse=True))

plt.bar(ordo.keys(), ordo.values(), color='lightskyblue',label="SpaCy")
plt.gcf().subplots_adjust(bottom = 0.25,top=0.95) 

plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(dpi=80)
fig.set_figheight(6)
fig.set_figwidth(12)
fig.suptitle('Comparatif erreur TreeTagger SpaCy (tagFound_tagRef)',va='baseline')
ax = fig.add_subplot(1,1,1)
ax.yaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.5)
ax.set_axisbelow(True) 

t = range(0, 25, 1)
t = list(t)
for i in [0,5,10,15,20]:
    t.remove(i)

plt.gca().yaxis.set_ticks(t, minor = True)
plt.gca().yaxis.grid(True, which = 'both', color = 'lightgrey', zorder = 0)

ax.yaxis.set_ticklabels(t, minor = True)
ax.yaxis.set_tick_params(which = 'minor', length = 5, width = 1,
                           color = 'grey', labelsize = 10, labelcolor = 'grey')

ax.yaxis.set_tick_params(which = 'major', length = 10, width = 1,
                           color = 'black', labelsize = 12)
from collections import OrderedDict
ordo = OrderedDict(sorted(tab_aff_spacy.items(), key=lambda t: t[1],reverse=True))

plt.bar(ordo.keys(), ordo.values(), color='lightskyblue',label="SpaCy")

plt.bar(tab_aff_tree.keys(), tab_aff_tree.values(), color='lightgreen', label="TreeTagger")



plt.gcf().subplots_adjust(bottom = 0.25,top=0.95) 
ax.legend()
plt.xticks(rotation=90)

plt.savefig("comparatif_TreeTagger_SpaCy.png")

# %%
sum(list(tab_aff_spacy.values()))
# Out:
# 181

# %%
adj_noun_spacy =[]
for diff in tab_diffs_global :
    if diff["spacy"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["spacy"]["mot"].lower()]
        if diff["spacy"]["nature"] == "ADJ" and ref_tag == "NOUN" : 
            adj_noun_spacy.append(diff["spacy"]["mot"])
display(adj_noun_spacy)
# Out:
# ['jardins',
#  'safari',
#  'buffets',
#  'armoire',
#  'pente',
#  'bars',
#  'magasins',
#  'restaurants',
#  'vagues',
#  'lits',
#  'bouilloire',
#  'restaurant',
#  'restaurants',
#  'douche',
#  'lieux',
#  'bureau',
#  'bémol',
#  'dommage',
#  'piscine',
#  'séjour',
#  'soins',
#  'massages',
#  'Personnels']

# %%
verb_noun_spacy =[]
for diff in tab_diffs_global :
    if diff["spacy"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["spacy"]["mot"].lower()]
        if diff["spacy"]["nature"] == "VERB" and ref_tag == "NOUN" : 
            verb_noun_spacy.append(diff["spacy"]["mot"])
display(verb_noun_spacy)
# Out:
# ['mer',
#  'mer',
#  'déjeuner',
#  'déjeuner',
#  'mer',
#  'coucher',
#  'bar',
#  'déjeuner',
#  'forfait',
#  'mer',
#  'lever',
#  'Suites',
#  'vue',
#  'serviettes',
#  'déjeuner',
#  'bar',
#  'déjeuner',
#  'mer',
#  'jacuzzis',
#  'vigil',
#  'mer',
#  'déjeuner',
#  'fruits']

# %%
noun_adj_spacy =[]
for diff in tab_diffs_global :
    if diff["spacy"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["spacy"]["mot"].lower()]
        if diff["spacy"]["nature"] == "NOUN" and ref_tag == "ADJ" : 
            noun_adj_spacy.append(diff["spacy"]["mot"])
display(noun_adj_spacy)
# Out:
# ['junior',
#  'grossier',
#  'bel',
#  'bel',
#  'chaude',
#  'superbe',
#  'gratuite',
#  'cool',
#  'correct',
#  'médiocre',
#  'abordables',
#  'sympa',
#  'bel',
#  'sympa']

# %%
noun_adj_tree =[]
for diff in tab_diffs_global :
    if diff["treetag"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["treetag"]["mot"].lower()]
        if diff["treetag"]["nature"] == "NOUN" and ref_tag == "ADJ" : 
            noun_adj_tree.append(diff["treetag"]["mot"])
display(noun_adj_tree)
# Out:
# ['futée', 'troisième', 'solo', 'petits', 'moderne']

# %%
noun_pron_tree =[]
for diff in tab_diffs_global :
    if diff["treetag"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["treetag"]["mot"].lower()]
        if diff["treetag"]["nature"] == "NOUN" and ref_tag == "PRON" : 
            print(diff["treetag"])
            noun_pron_tree.append(diff["treetag"]["mot"])
display(noun_pron_tree)
# Out:
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.502753, 'NAM', '<unknown>', 0.362092)}
# {'mot': 'tout', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.941743,)}
# {'mot': "J'", 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.734369,)}
# {'mot': 'Tous', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.527255,)}
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.640283,)}
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.641522,)}
# {'mot': 'Tous', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.614362,)}
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.641522,)}
# {'mot': 'Ils', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.760832,)}
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.600188,)}
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.641522,)}
# {'mot': 'Il', 'nature': 'NOUN', 'tag': 'NOM', 'acc': (0.758229,)}
# ['Il', 'tout', "J'", 'Tous', 'Il', 'Il', 'Tous', 'Il', 'Ils', 'Il', 'Il', 'Il']

# %%
pron_det_tree =[]
for diff in tab_diffs_global :
    if diff["treetag"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["treetag"]["mot"].lower()]
        if diff["treetag"]["nature"] == "PRON" and ref_tag == "DET" : 
            print(diff["treetag"])
            pron_det_tree.append(diff["treetag"]["mot"])
display(pron_det_tree)
# Out:
# {'mot': 'chaque', 'nature': 'PRON', 'tag': 'PRO:IND', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'les', 'nature': 'PRON', 'tag': 'PRO:PER', 'acc': (0.797243,)}
# {'mot': 'chaque', 'nature': 'PRON', 'tag': 'PRO:IND', 'acc': (1.0,)}
# {'mot': 'cette', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'le', 'nature': 'PRON', 'tag': 'PRO:PER', 'acc': (0.645676,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'cet', 'nature': 'PRON', 'tag': 'PRO:DEM', 'acc': (1.0,)}
# {'mot': 'chaque', 'nature': 'PRON', 'tag': 'PRO:IND', 'acc': (1.0,)}
# ...

# %%
pron_adj_tree =[]
for diff in tab_diffs_global :
    if diff["treetag"]["mot"].lower() in list(list_terme):
        ref_tag = list_terme[diff["treetag"]["mot"].lower()]
        if diff["treetag"]["nature"] == "PRON" and ref_tag == "ADJ" : 
            print(diff["treetag"])
            pron_adj_tree.append(diff["treetag"]["mot"])
display(pron_adj_tree)
# Out:
# {'mot': 'quelques', 'nature': 'PRON', 'tag': 'PRO:IND', 'acc': (1.0,)}
# {'mot': 'quel', 'nature': 'PRON', 'tag': 'PRO:REL', 'acc': (1.0,)}
# {'mot': 'quelque', 'nature': 'PRON', 'tag': 'PRO:IND', 'acc': (1.0,)}
# {'mot': 'quelques', 'nature': 'PRON', 'tag': 'PRO:IND', 'acc': (1.0,)}
# ['quelques', 'quel', 'quelque', 'quelques']

# %% [markdown]
# AUX	auxiliary
#
#
# INTJ	interjection
#
#
#
#
# PART	particle
# X	other
#
# DET	determiner
# ADJ	adjective
# ADV	adverb
# SCONJ	subordinating conjunction
# CONJ	conjunction
# CCONJ	coordinating conjunction
# PRON	pronoun
# NUM	numeral
# PROPN	proper noun
# NOUN	noun
# PUNCT	punctuation
# SYM	symbol
# VERB	verb
#
# SPACE	space
#
#
#
# TreeTagger
#
# SENT	sentence tag
#
# ABR	abreviation
#
# INT	interjection
# DET:ART	article
# DET:POS	possessive pronoun (ma, ta, ...)
# ADJ	adjective
# ADV	adverb
# KON	conjunction
# PRO	    pronoun
# PRO:DEM	demonstrative pronoun
# PRO:IND	indefinite pronoun
# PRO:PER	personal pronoun
# PRO:POS	possessive pronoun (mien, tien, ...)
# PRO:REL	relative pronoun
# PRP	preposition
# PRP:det	preposition plus article (au,du,aux,des)
# NUM	numeral
# NAM	proper name
# NOM	noun
# PUN	punctuation
# PUN:cit	punctuation citation
# SYM	symbol
# VER:cond	verb conditional
# VER:futu	verb futur
# VER:impe	verb imperative
# VER:impf	verb imperfect
# VER:infi	verb infinitive
# VER:pper	verb past participle
# VER:ppre	verb present participle
# VER:pres	verb present
# VER:simp	verb simple past
# VER:subi	verb subjunctive imperfect
# VER:subp	verb subjunctive present

# %%
from spellchecker import SpellChecker

spell = SpellChecker(language="fr")

# find those words that may be misspelled
misspelled = spell.unknown(['vace'])
for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))
# Out:
# face

# %%
print(spell.correction("etaiz"))
# Out:
# etait

# %%
s= "hôtel très propre et bien agencé, personnels très accueillant et très serviable, nourriture très varié et de bonne qualité équipements piscine , salle de sport "
print(s)
# Out:
# hôtel très propre et bien agencé, personnels très accueillant et très serviable, nourriture très varié et de bonne qualité équipements piscine , salle de sport

# %%
s.replace(","," , ")
# Out:
# 'hôtel très propre et bien agencé ,  personnels très accueillant et très serviable ,  nourriture très varié et de bonne qualité équipements piscine  ,  salle de sport '

# %%
import sys
import json
import treetaggerwrapper
import warnings

from spellchecker import SpellChecker

spell = SpellChecker(language="fr")

tagger = treetaggerwrapper.TreeTagger(TAGLANG='fr',TAGOPT="-token -lemma -sgml -quiet")

tags = {
    "VER:cond":"VERB",
    "VER:futu":"VERB",
    "VER:impe":"VERB",
    "VER:impf":"VERB",
    "VER:infi":"VERB",
    "VER:pper":"VERB",
    "VER:ppre":"VERB",
    "VER:pres":"VERB",
    "VER:simp":"VERB",
    "VER:subi":"VERB",
    "VER:subp":"VERB",
    "VERB" : "VERB",
    "SYM" :"SYM",
    "PUN:cit" : "PUNCT",
    "PUN" : "PUNCT",
    "PUNCT" : "PUNCT",
    "NAM" : "PROPN",
    "PROPN" : "PROPN",
    "NOM" : "NOUN",
    "NOUN" : "NOUN",
    "NUM" : "NUM",
    "PRP" : "ADP",
    "PRP:det" : "DET",
    "ADP" : "ADP",
    "PRO" : "PRON",
    "PRO:DEM" : "PRON",
    "PRO:IND" : "PRON",
    "PRO:PER" : "PRON",
    "PRO:POS" : "PRON",
    "PRO:REL" : "PRON",
    "PRON" : "PRON",
    "CONJ" : "KON",
    "CCONJ" : "KON",
    "SCONJ" : "KON",
    "KON" : "KON",
    "ADV" : "ADV",
    "ADJ" : "ADJ",
    "DET:ART" : "DET",
    "DET:POS" : "DET",
    "DET" : "DET",
    "INT" : "INTJ",
    "INTJ" : "INTJ",
    "PART" : "PART",
    "X" : "X",
    "SENT" : "PUNCT",
    "ABR" : "X"
}
# Out:
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:740: FutureWarning: Possible nested set at position 8
#   re.IGNORECASE | re.VERBOSE)
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:2044: FutureWarning: Possible nested set at position 152
#   re.VERBOSE | re.IGNORECASE)
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:2067: FutureWarning: Possible nested set at position 409
#   UrlMatch_re = re.compile(UrlMatch_expression, re.VERBOSE | re.IGNORECASE)
# /Users/bca/Workspace/TER_M1_Hotel_Advisor/WebService_TALN/python/env/lib/python3.7/site-packages/treetaggerwrapper.py:2079: FutureWarning: Possible nested set at position 192
#   EmailMatch_re = re.compile(EmailMatch_expression, re.VERBOSE | re.IGNORECASE)

# %%
def tagToObj(sentArray):
    sentTab = []
    for t in sentArray:
        if len(t) >1 :
            tag = t[1];
            if t[2]=="ce" or t[2]=="chaque":
                tag = "DET"
            sentTab.append({"mot" : t[0], "nature" : tags[tag],"tag":t[1],"lemme":t[2]})
    return sentTab

def posTaggingTreeTagger(text) :
    tags = tagger.tag_text(text)
    taggedText = treetaggerwrapper.make_tags(tags,allow_extra = True)
    return tagToObj(taggedText)
import re
def spellCorrectSentence(sent) :
    sent = sent.replace(","," , ")
    sent = sent.replace("."," . ")
    sent = re.sub("  +", ' ', sent)
    words = sent.split(" ")
    words_corrected = []
    for word in words :
        if len(word.split("'")) < 2 and word != '':
            words_corrected.append(spell.correction(word))
        else :
            words_corrected.append(word)
    return " ".join(words_corrected)

# %%
posTaggingTreeTagger(spellCorrectSentence(s))
# Out:
# hôtel très propre et bien agencé ,  personnels très accueillant et très serviable ,  nourriture très varié et de bonne qualité équipements piscine  ,  salle de sport
# hôtel très propre et bien agencé , personnels très accueillant et très serviable , nourriture très varié et de bonne qualité équipements piscine , salle de sport
# ['hôtel', 'très', 'propre', 'et', 'bien', 'agencé', ',', 'personnels', 'très', 'accueillant', 'et', 'très', 'serviable', ',', 'nourriture', 'très', 'varié', 'et', 'de', 'bonne', 'qualité', 'équipements', 'piscine', ',', 'salle', 'de', 'sport', '']
# [{'mot': 'hôtel', 'nature': 'NOUN', 'tag': 'NOM', 'lemme': 'hôtel'},
#  {'mot': 'très', 'nature': 'ADV', 'tag': 'ADV', 'lemme': 'très'},
#  {'mot': 'propre', 'nature': 'ADJ', 'tag': 'ADJ', 'lemme': 'propre'},
#  {'mot': 'et', 'nature': 'KON', 'tag': 'KON', 'lemme': 'et'},
#  {'mot': 'bien', 'nature': 'ADJ', 'tag': 'ADJ', 'lemme': 'bien'},
#  {'mot': 'agence', 'nature': 'NOUN', 'tag': 'NOM', 'lemme': 'agence'},
# ...
