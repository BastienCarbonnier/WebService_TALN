# %% [markdown]
# # Test spaCy

# %% [markdown]
# Essais décomposition et affichage sous forme de graphe :

# %%
import spacy
from spacy import displacy

nlp = spacy.load("fr_core_news_sm")
doc = nlp("La chambre était très sale et le personnel désagréable.")

displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="644-0" class="displacy" width="1625" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">chambre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">était</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# ...

# %%
doc = nlp("le personnel absolument charmant et très serviable chambre spacieuse, confortable et bien équipée quartier très vivant avec des restaurants très animés et de qualité transports en commun très proches RESULTAT très positif")

displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="883-0" class="displacy" width="5650" height="1012.0" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">personnel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">absolument</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# ...

# %% [markdown]
# POS	DESCRIPTION	EXAMPLES
# ADJ	adjective	big, old, green, incomprehensible, first
# ADP	adposition	in, to, during
# ADV	adverb	very, tomorrow, down, where, there
# AUX	auxiliary	is, has (done), will (do), should (do)
# CONJ	conjunction	and, or, but
# CCONJ	coordinating conjunction	and, or, but
# DET	determiner	a, an, the
# INTJ	interjection	psst, ouch, bravo, hello
# NOUN	noun	girl, cat, tree, air, beauty
# NUM	numeral	1, 2017, one, seventy-seven, IV, MMXIV
# PART	particle	's, not,
# PRON	pronoun	I, you, he, she, myself, themselves, somebody
# PROPN	proper noun	Mary, John, London, NATO, HBO
# PUNCT	punctuation	., (, ), ?
# SCONJ	subordinating conjunction	if, while, that
# SYM	symbol	$, %, §, ©, +, −, ×, ÷, =, :), 😝
# VERB	verb	run, runs, running, eat, ate, eating
# X	other	sfpksdpsxmsa
# SPACE	space

# %%
phrase = [
    {"index": 0, "mot": "La", "type": "DET"}, 
    {"index": 1, "mot": "grande", "type": "ADJ"}, 
    {"index": 2, "mot": "chambre", "type": "NOUN"}, 
    {"index": 3, "mot": "vraiment", "type": "ADV"}, 
    {"index": 4, "mot": "noire", "type": "ADJ"}, 
    {"index": 5, "mot": "était", "type": "AUX"}, 
    {"index": 6, "mot": "sale", "type": "ADJ"},
    {"index": 7, "mot": "comme", "type": "ADP"}, 
    {"index": 8, "mot": "la", "type": "DET"}, 
    {"index": 9, "mot": "petite", "type": "ADJ"}, 
    {"index": 10, "mot": "salle", "type": "NOUN"}, 
    {"index": 11, "mot": "de", "type": "ADP"}, 
    {"index": 12, "mot": "bain", "type": "NOUN"}
]

# %%
index_adj = []
# Return list of position of index of adjectifs a noun
def findAdjectifForNouns(phrase,i_nom):
    i_d = i_nom+1
    i_g = i_nom-1
    deja_trouve = False

    while i_d <len(phrase):
        #if deja_trouve and (phrase[i_d]["type"]!="ADJ" or phrase[i_d]["type"]!="ADV" or phrase[i_d]["type"]!="AUX" or phrase[i_d]["type"]!="VERB"):
           # break
        if phrase[i_d]["type"]=="ADJ":
            index_adj.append(i_d)
            deja_trouve = True
            i_d+=1
        elif phrase[i_d]["type"]=="ADV":
            i_d+=1
        elif phrase[i_d]["type"]=="AUX":
            i_d+=1
        else:
            break

    deja_trouve = False
    while i_g >=0:
        #if deja_trouve and (phrase[i_g]["type"]!="ADJ" or phrase[i_g]["type"]!="ADV" or phrase[i_g]["type"]!="AUX" or phrase[i_g]["type"]!="VERB"):
            #break
        if phrase[i_g]["type"]=="ADJ":
            index_adj.append(i_g)
            deja_trouve = True
            i_g-=1
        elif phrase[i_g]["type"]=="ADV":
            i_g-=1
        elif phrase[i_g]["type"]=="AUX":
            i_g-=1
        else:
            break
    return index_adj

display(findAdjectifForNouns(phrase,10))
# Out:
# [9]
